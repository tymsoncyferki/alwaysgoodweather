# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from plotnine import geom_point, ggplot, aes, geom_line

# %%
data = pd.read_csv('locations.csv')

# %%
(ggplot(data, aes('latitude', 'hmax'))
 + geom_line())
# Out:
# <Figure Size: (640 x 480)>

# %%
(ggplot(data, aes('longitude', 'hmax'))
 + geom_line())
# Out:
# <Figure Size: (640 x 480)>

# %%
y = data['hmax']  # only for tests
X = data[['latitude', 'longitude']]
lm = LinearRegression().fit(X.values, y.values)

# %%
bialystok = lm.predict(np.array([[53.175887, 19.745537]]))

# %%
bialystok
# Out:
# array([32.54133749])

# %%
lm.coef_
# Out:
# array([0.33288283, 2.68381967])
